# %%
import pandas as pd

data_2024Q1 = pd.read_csv(
    "data/2024Q1.csv",
    delimiter="|",
    header=None,
    nrows=100_000
)
# Out:
# C:\Users\zachl\AppData\Local\Temp\ipykernel_56396\585709045.py:3: DtypeWarning: Columns (105) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2024Q1 = pd.read_csv(

# %%
data_2024Q1
# Out:
#        0          1      2   3                       4    \
# 0      NaN  137581448  12024   R                   Other
# 1      NaN  137581448  22024   R                   Other
# 2      NaN  137581448  32024   R                   Other
# 3      NaN  137581448  42024   R                   Other
# 4      NaN  137581448  52024   R                   Other
# ...    ...        ...    ...  ..                     ...
# 99995  NaN  137590079  52024   R  Freedom Mortgage Corp.
# 99996  NaN  137590079  62024   R  Freedom Mortgage Corp.
# 99997  NaN  137590079  72024   R  Freedom Mortgage Corp.
# 99998  NaN  137590079  82024   R  Freedom Mortgage Corp.
# 99999  NaN  137590079  92024   R  Freedom Mortgage Corp.
#
#                           5    6      7      8         9    ...  100  101  \
# 0                       Other  NaN  6.990  6.990  450000.0  ...  NaN    7
# 1                       Other  NaN  6.990  6.990  450000.0  ...  NaN    7
# ...
